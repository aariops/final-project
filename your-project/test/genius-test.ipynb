# %%
import pandas as pd
import numpy as np
from tqdm.notebook import tqdm
import json
import os
import datetime
import lyricsgenius as genius

# %%
artist_list = ["Alabama Shakes", "Blondie", "CHVRCHES", "Crystal Castles", "Eurythmics", "Fleetwood Mac", "Garbage", "Goldfrapp", "London Grammar", "No Doubt", "Miami Sound Machine", "Moloko", "Paramore", "Portishead", "Skunk Anasie", "Sleigh Bells", "Texas", "Yeah Yeah Yeahs"]

# %%
geniusCreds = "o2903wOf7ZskiIrmaHxXMyNev-N8vENdPNsaSlH9gU2cuIwK75Xfu4M3-nqM4bt4"

# %%
api = genius.Genius(geniusCreds, verbose =False, excluded_terms = ["Remix", "edit", "(Acoustic)", "Rework", "(Live)", "(Demo)", "TBA", "FULL LENGTH", "Billboard", "BBC", "bootleg", 'فارسی', "Türkçe", "Aşk Şarkısı", "instrumental"], sleep_time=0.2, remove_section_headers = True, skip_non_songs = True)

# %%
def crawler(lst):
    for name in tqdm(lst):
        try:
            artist = api.search_artist(name, per_page=50)
            artist.save_lyrics()
            print(str(name) + " json saved")
        except:
            print("failed for", name)
            file = open(r"not-working.txt","a")
            file.write(name)
            file.close()

crawler(artist_list)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=18.0), HTML(value='')))
# Wrote `Lyrics_AlabamaShakes.json`
# Alabama Shakes json saved
# Wrote `Lyrics_Blondie.json`
# Blondie json saved
# Wrote `Lyrics_CHVRCHES.json`
# CHVRCHES json saved
# Wrote `Lyrics_CrystalCastles.json`
# Crystal Castles json saved
# Wrote `Lyrics_Eurythmics.json`
# Eurythmics json saved
# Wrote `Lyrics_FleetwoodMac.json`
# Fleetwood Mac json saved
# Wrote `Lyrics_Garbage.json`
# Garbage json saved
# Wrote `Lyrics_Goldfrapp.json`
# Goldfrapp json saved
# Wrote `Lyrics_LondonGrammar.json`
# London Grammar json saved
# Wrote `Lyrics_NoDoubt.json`
# No Doubt json saved
# Wrote `Lyrics_MiamiSoundMachine.json`
# Miami Sound Machine json saved
# Wrote `Lyrics_Moloko.json`
# Moloko json saved
# Wrote `Lyrics_Paramore.json`
# Paramore json saved
# Wrote `Lyrics_Portishead.json`
# Portishead json saved
# Wrote `Lyrics_SkunkAnansie.json`
# Skunk Anasie json saved
# Wrote `Lyrics_SleighBells.json`
# Sleigh Bells json saved
# Wrote `Lyrics_Texas.json`
# Texas json saved
# Wrote `Lyrics_YeahYeahYeahs.json`
# Yeah Yeah Yeahs json saved

# %% [markdown]
# ## Building the dataframe

# %%
#initailizing empty dataframe for concat each json info
maindata = pd.DataFrame()    

for filename in os.listdir():
    if filename.endswith(".json"): 
        with open(filename) as json_data:
           
            data = json.load(json_data)
            
            #getting artist name and release date
            songs = data.get("songs")
            songs_df = pd.DataFrame(songs)
             
            #getting artist name and release date
            songs_df["artist_name"] = data.get("name")
            songs_df['date'] = [i.get("release_date") for i in songs]

            #getting album name
            album_lst = [i.get("album") for i in songs]
            songs_df["album"] = [i.get("name") if i else "---" for i in album_lst]


            maindata = pd.concat([maindata, songs_df])
              
        
maindata
# Out:
#     annotation_count        api_path apple_music_id  \
# 0                  4     /songs/1640      303097827
# 1                  3  /songs/1780425      206869247
# 2                  4   /songs/437256      303097836
# 3                  1   /songs/231022      206869846
# 4                  3  /songs/1476682      303097826
# ..               ...             ...            ...
# 89                 0  /songs/4242258     1144981878
# 90                 0  /songs/3610176     1193713260
# 91                 0  /songs/3609534     1193716173
# 92                 0  /songs/3020961           None
# 93                 0  /songs/4411274     1193713256
#
#                                apple_music_player_url  \
# 0    https://genius.com/songs/1640/apple_music_player
# 1   https://genius.com/songs/1780425/apple_music_p...
# 2   https://genius.com/songs/437256/apple_music_pl...
# 3   https://genius.com/songs/231022/apple_music_pl...
# 4   https://genius.com/songs/1476682/apple_music_p...
# ..                                                ...
# 89  https://genius.com/songs/4242258/apple_music_p...
# 90  https://genius.com/songs/3610176/apple_music_p...
# 91  https://genius.com/songs/3609534/apple_music_p...
# 92  https://genius.com/songs/3020961/apple_music_p...
# 93  https://genius.com/songs/4411274/apple_music_p...
#
#                                           description  \
# 0   {'plain': 'Eurythmics’ bold musical experiment...
# 1                                      {'plain': '?'}
# 2   {'plain': '“Sisters Are Doin' It For Themselve...
# 3                                      {'plain': '?'}
# 4   {'plain': 'Released as a sngle in Sweet Dreams...
# ..                                                ...
# 89                                     {'plain': '?'}
# 90                                     {'plain': '?'}
# 91                                     {'plain': '?'}
# 92                                     {'plain': '?'}
# 93                                     {'plain': '?'}
#
#                                         embed_content  \
# 0   <div id='rg_embed_link_1640' class='rg_embed_l...
# 1   <div id='rg_embed_link_1780425' class='rg_embe...
# 2   <div id='rg_embed_link_437256' class='rg_embed...
# 3   <div id='rg_embed_link_231022' class='rg_embed...
# 4   <div id='rg_embed_link_1476682' class='rg_embe...
# ..                                                ...
# 89  <div id='rg_embed_link_4242258' class='rg_embe...
# 90  <div id='rg_embed_link_3610176' class='rg_embe...
# 91  <div id='rg_embed_link_3609534' class='rg_embe...
# 92  <div id='rg_embed_link_3020961' class='rg_embe...
# 93  <div id='rg_embed_link_4411274' class='rg_embe...
#
#                                            fact_track  featured_video  \
# 0   {'provider': 'spotify', 'external_url': 'https...            True
# 1                                                 NaN            True
# 2                                                 NaN           False
# 3                                                 NaN           False
# 4                                                 NaN           False
# ..                                                ...             ...
# 89                                                NaN           False
# 90                                                NaN           False
# 91                                                NaN           False
# 92                                                NaN           False
# 93                                                NaN           False
#
#                                            full_title  \
# 0       Sweet Dreams (Are Made of This) by Eurythmics
# 1             Here Comes the Rain Again by Eurythmics
# 2   Sisters Are Doin' It For Themselves by Eurythm...
# 3                      Thorn in My Side by Eurythmics
# 4                    Love Is a Stranger by Eurythmics
# ..                                                ...
# 89  Ride a White Horse (Ewan Pearson Disco Odyssey...
# 90  Satin Chic (Through The Mystic Mix, Dimension ...
# 91              You Never Know (Múm Mix) by Goldfrapp
# 92              Eat yourself (corrected) by Goldfrapp
# 93  Satin Chic (Bombay Mix by The Shortwave Set) b...
#
#                            header_image_thumbnail_url  ...  \
# 0   https://images.genius.com/23250e41f0a185c77726...  ...
# 1   https://images.genius.com/58de3105f03141970b69...  ...
# 2   https://images.genius.com/6b97d280eb1043a7c527...  ...
# 3   https://images.genius.com/38552aa27c81a056fb99...  ...
# 4   https://images.genius.com/7e473cb22bd3ce2cde70...  ...
# ..                                                ...  ...
# 89  https://images.genius.com/c5657449a48becc6e199...  ...
# 90  https://images.genius.com/adde34e488d44f30994a...  ...
# 91  https://images.genius.com/5d801caeef6602ec88f4...  ...
# 92  https://images.genius.com/9914ea30f67fbc2a4315...  ...
# 93  https://images.genius.com/c5657449a48becc6e199...  ...
#
#                                        primary_artist  \
# 0   {'api_path': '/artists/829', 'header_image_url...
# 1   {'api_path': '/artists/829', 'header_image_url...
# 2   {'api_path': '/artists/829', 'header_image_url...
# 3   {'api_path': '/artists/829', 'header_image_url...
# 4   {'api_path': '/artists/829', 'header_image_url...
# ..                                                ...
# 89  {'api_path': '/artists/107255', 'header_image_...
# 90  {'api_path': '/artists/107255', 'header_image_...
# 91  {'api_path': '/artists/107255', 'header_image_...
# 92  {'api_path': '/artists/107255', 'header_image_...
# 93  {'api_path': '/artists/107255', 'header_image_...
#
#                                      producer_artists  \
# 0   [{'api_path': '/artists/400870', 'header_image...
# 1   [{'api_path': '/artists/400870', 'header_image...
# 2   [{'api_path': '/artists/400870', 'header_image...
# 3                                                  []
# 4   [{'api_path': '/artists/1218018', 'header_imag...
# ..                                                ...
# 89  [{'api_path': '/artists/107255', 'header_image...
# 90  [{'api_path': '/artists/107255', 'header_image...
# 91  [{'api_path': '/artists/107255', 'header_image...
# 92                                                 []
# 93  [{'api_path': '/artists/107255', 'header_image...
#
#                                    song_relationships verified_annotations_by  \
# 0   [{'relationship_type': 'samples', 'type': 'sam...                      []
# 1   [{'relationship_type': 'samples', 'type': 'sam...                      []
# 2   [{'relationship_type': 'samples', 'type': 'sam...                      []
# 3   [{'relationship_type': 'samples', 'type': 'sam...                      []
# 4   [{'relationship_type': 'samples', 'type': 'sam...                      []
# ..                                                ...                     ...
# 89  [{'relationship_type': 'samples', 'type': 'sam...                      []
# 90  [{'relationship_type': 'samples', 'type': 'sam...                      []
# 91  [{'relationship_type': 'samples', 'type': 'sam...                      []
# 92  [{'relationship_type': 'samples', 'type': 'sam...                      []
# 93  [{'relationship_type': 'samples', 'type': 'sam...                      []
#
#    verified_contributors  verified_lyrics_by  \
# 0                     []                  []
# 1                     []                  []
# 2                     []                  []
# 3                     []                  []
# 4                     []                  []
# ..                   ...                 ...
# 89                    []                  []
# 90                    []                  []
# 91                    []                  []
# 92                    []                  []
# 93                    []                  []
#
#                                        writer_artists  \
# 0   [{'api_path': '/artists/400870', 'header_image...
# 1   [{'api_path': '/artists/400870', 'header_image...
# 2   [{'api_path': '/artists/400870', 'header_image...
# 3                                                  []
# 4   [{'api_path': '/artists/400870', 'header_image...
# ..                                                ...
# 89  [{'api_path': '/artists/555736', 'header_image...
# 90  [{'api_path': '/artists/555736', 'header_image...
# 91  [{'api_path': '/artists/555736', 'header_image...
# 92  [{'api_path': '/artists/107255', 'header_image...
# 93  [{'api_path': '/artists/555736', 'header_image...
#
#                                                lyrics artist_name        date
# 0   Sweet dreams are made of this\nWho am I to dis...  Eurythmics  1983-01-21
# 1   Here comes the rain again\nFalling on my head ...  Eurythmics  1984-01-12
# 2   Now there was a time when they used to say\nTh...  Eurythmics  1985-10-01
# 3   You gave me such a bad time\nTried to hurt me,...  Eurythmics        None
# 4   Love is a stranger\nIn an open car\nTo tempt y...  Eurythmics        None
# ..                                                ...         ...         ...
# 89  Now take me dancing at the disco\nWhere you bu...   Goldfrapp        None
# 90  You're so satin chic\nLook rich, talking cheap...   Goldfrapp        None
# 91  I love you\nSteel painted eyes\nFeels like sno...   Goldfrapp  2006-05-01
# 92  If you don't eat yourself,\nNo doubt the blade...   Goldfrapp  2008-02-22
# 93  You're so satin chic\nLook rich, talking cheap...   Goldfrapp        None
#
# [1987 rows x 42 columns]

# %%
maindata.columns
# Out:
# Index(['annotation_count', 'api_path', 'apple_music_id',
#        'apple_music_player_url', 'description', 'embed_content',
#        'featured_video', 'full_title', 'header_image_thumbnail_url',
#        'header_image_url', 'id', 'lyrics_owner_id', 'lyrics_state', 'path',
#        'pyongs_count', 'recording_location', 'release_date',
#        'release_date_for_display', 'song_art_image_thumbnail_url',
#        'song_art_image_url', 'stats', 'title', 'title_with_featured', 'url',
#        'current_user_metadata', 'album', 'custom_performances',
#        'description_annotation', 'featured_artists',
#        'lyrics_marked_complete_by', 'media', 'primary_artist',
#        'producer_artists', 'song_relationships', 'verified_annotations_by',
#        'verified_contributors', 'verified_lyrics_by', 'writer_artists',
#        'lyrics', 'fact_track', 'artist_name', 'date', 'song_story_embed_url',
#        'song_story'],
#       dtype='object')

# %%
maindata = maindata[['artist_name', 'title', 'album', 'lyrics', 'date', 'url']]

# %%
maindata
# Out:
#    artist_name                                              title  \
# 0   Eurythmics                    Sweet Dreams (Are Made of This)
# 1   Eurythmics                          Here Comes the Rain Again
# 2   Eurythmics                Sisters Are Doin’ It For Themselves
# 3   Eurythmics                                   Thorn in My Side
# 4   Eurythmics                                 Love Is a Stranger
# ..         ...                                                ...
# 89   Goldfrapp  Ride a White Horse (Ewan Pearson Disco Odyssey...
# 90   Goldfrapp  Satin Chic (Through The Mystic Mix, Dimension ...
# 91   Goldfrapp                           You Never Know (Múm Mix)
# 92   Goldfrapp                           Eat yourself (corrected)
# 93   Goldfrapp       Satin Chic (Bombay Mix by The Shortwave Set)
#
#                               album  \
# 0   Sweet Dreams (Are Made of This)
# 1                             Touch
# 2               Be Yourself Tonight
# 3                           Revenge
# 4   Sweet Dreams (Are Made of This)
# ..                              ...
# 89                   We Are Glitter
# 90                   We Are Glitter
# 91                   We Are Glitter
# 92                              ---
# 93                   We Are Glitter
#
#                                                lyrics        date  \
# 0   Sweet dreams are made of this\nWho am I to dis...  1983-01-21
# 1   Here comes the rain again\nFalling on my head ...  1984-01-12
# 2   Now there was a time when they used to say\nTh...  1985-10-01
# 3   You gave me such a bad time\nTried to hurt me,...        None
# 4   Love is a stranger\nIn an open car\nTo tempt y...        None
# ..                                                ...         ...
# 89  Now take me dancing at the disco\nWhere you bu...        None
# 90  You're so satin chic\nLook rich, talking cheap...        None
# 91  I love you\nSteel painted eyes\nFeels like sno...  2006-05-01
# 92  If you don't eat yourself,\nNo doubt the blade...  2008-02-22
# 93  You're so satin chic\nLook rich, talking cheap...        None
#
#                                                   url
# 0   https://genius.com/Eurythmics-sweet-dreams-are...
# 1   https://genius.com/Eurythmics-here-comes-the-r...
# 2   https://genius.com/Eurythmics-sisters-are-doin...
# 3   https://genius.com/Eurythmics-thorn-in-my-side...
# 4   https://genius.com/Eurythmics-love-is-a-strang...
# ..                                                ...
# 89  https://genius.com/Goldfrapp-ride-a-white-hors...
# 90  https://genius.com/Goldfrapp-satin-chic-throug...
# 91  https://genius.com/Goldfrapp-you-never-know-mu...
# 92  https://genius.com/Goldfrapp-eat-yourself-corr...
# 93  https://genius.com/Goldfrapp-satin-chic-bombay...
#
# [1987 rows x 6 columns]

# %%
#export to work on a different notebook
maindata.to_csv('test.csv')
